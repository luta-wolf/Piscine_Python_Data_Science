# %%
pip install tabula-py
# Out:
# Requirement already satisfied: tabula-py in /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages (2.5.1)
# Requirement already satisfied: numpy in /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages (from tabula-py) (1.21.6)
# Requirement already satisfied: pandas>=0.25.3 in /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages (from tabula-py) (1.3.5)
# Requirement already satisfied: distro in /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages (from tabula-py) (1.7.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages (from pandas>=0.25.3->tabula-py) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->tabula-py) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import json
import time
import tabula

# %%
tabula.convert_into('data/Daily-Reference-Values-(DRVs)-under-the-New-NFL.pdf', output_format="csv", pages='all', output_path='data/Daily-Reference-Values-(DRVs)-under-the-New-NFL.csv')

# %%
df0 = pd.read_csv('data/Daily-Reference-Values-(DRVs)-under-the-New-NFL.csv')
df0
# Out:
#   DRVs - Food Components       Unnamed: 1                      Unnamed: 2  \
# 0        Food\rComponent  Unit of measure  Adults and Children ≥ 4\ryears
# 1                    Fat        Grams (g)                             178
# 2          Saturated fat        Grams (g)                             120
# 3            Cholesterol  Milligrams (mg)                             300
# 4   Total\rcarbohydrates        Grams (g)                            1275
# 5                 Sodium  Milligrams (mg)                           2,300
# 6          Dietary Fiber        Grams (g)                             128
# 7                Protein        Grams (g)                             150
# 8           Added sugars        Grams (g)                             150
#
#                    Unnamed: 3                   Unnamed: 4  \
# 0  Infants through 12\rmonths  Children 1 through 3\ryears
# 1                          30                          239
# 2                         NaN                          210
# 3                         NaN                          300
# 4                          95                         2150
# 5                         NaN                        1,500
# 6                         NaN                          214
# 7                         NaN                          213
# 8                         NaN                          225
#
#                             Unnamed: 5
# 0  Pregnant women and\rlactating women
# 1                                  178
# 2                                  120
# 3                                  300
# 4                                 1275
# 5                                2,300
# 6                                  128
# 7                                  NaN
# 8                                  150

# %%
daily_reference = pd.DataFrame()
daily_reference['Nutrient'] = df0['DRVs - Food Components'][1:]
daily_reference['Daily dose in G'] = df0['Unnamed: 2'][1:].str[1:]
daily_reference['Daily dose in G'][daily_reference['Nutrient'] == 'Cholesterol'] = 0.3
daily_reference['Daily dose in G'][daily_reference['Nutrient'] == 'Sodium'] = 2.3
daily_reference['Daily dose in G'] = daily_reference['Daily dose in G'].astype(float)
daily_reference
# Out:
#                Nutrient  Daily dose in G
# 1                   Fat             78.0
# 2         Saturated fat             20.0
# 3           Cholesterol              0.3
# 4  Total\rcarbohydrates            275.0
# 5                Sodium              2.3
# 6         Dietary Fiber             28.0
# 7               Protein             50.0
# 8          Added sugars             50.0

# %%
tabula.convert_into('data/Reference_Daily_Intakes_RDIs_in_the_New_Nutrition_Facts_Label.pdf', output_format="csv", pages='all', output_path='data/Reference_Daily_Intakes_RDIs_in_the_New_Nutrition_Facts_Label.csv')

# %%
df1 = pd.read_csv('/goinfre/einterdi/rush01/data/Reference_Daily_Intakes_RDIs_in_the_New_Nutrition_Facts_Label.csv')
df1.drop(df1.tail(3).index,inplace=True)
df1.drop(df1.head(1).index,inplace=True)
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/zz/zyxvpxvq6csfxvn_n003vrph00yy5m/T/ipykernel_98045/4235572523.py in <module>
# ----> 1 df1 = pd.read_csv('/goinfre/einterdi/rush01/data/Reference_Daily_Intakes_RDIs_in_the_New_Nutrition_Facts_Label.csv')
#       2 df1.drop(df1.tail(3).index,inplace=True)
#       3 df1.drop(df1.head(1).index,inplace=True)
#       4 df1
#
# /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /opt/goinfre/einterdi/Piscine_Python_Data_Science/venv/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/goinfre/einterdi/rush01/data/Reference_Daily_Intakes_RDIs_in_the_New_Nutrition_Facts_Label.csv'

# %%
df_add1 = df1[(df1['Unnamed: 1'] == 'Milligrams (mg)') 
  | (df1['Unnamed: 1'] == 'Milligrams NE5 (mg)') | (df1['Unnamed: 1'] == 'Milligrams (mg)4')]
df_add1['Unnamed: 2'] = df_add1['Unnamed: 2'].str.replace(',', '')
df_add1['Unnamed: 2'] = df_add1['Unnamed: 2'].astype(float) / 1000
df_add1.drop(columns=['Unnamed: 1', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], inplace=True)
df_add1.rename(columns={'RDIs - Nutrients' : 'Nutrient', 'Unnamed: 2' : 'Daily dose in G'}, inplace=True)
df_add1
# Out:
# /var/folders/zz/zyxvpxvq6csfxvn_n003vm3w00yx0z/T/ipykernel_78052/275473101.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_add1['Unnamed: 2'] = df_add1['Unnamed: 2'].str.replace(',', '')
# /var/folders/zz/zyxvpxvq6csfxvn_n003vm3w00yx0z/T/ipykernel_78052/275473101.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_add1['Unnamed: 2'] = df_add1['Unnamed: 2'].astype(float) / 1000
# /var/folders/zz/zyxvpxvq6csfxvn_n003vm3w00yx0z/T/ipykernel_78052/275473101.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_add1.drop(columns=['Unnamed: 1', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], inplace=True)
# /var/folders/zz/zyxvpxvq6csfxvn_n003vm3w00yx0z/T/ipykernel_78052/275473101.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_add1.rename(columns={'RDIs - Nutrients' : 'Nutrient', 'Unnamed: 2' : 'Daily dose in G'}, inplace=True)
#             Nutrient  Daily dose in G
# 2          Vitamin C           0.0900
# 3            Calcium           1.3000
# 4               Iron           0.0180
# 6          Vitamin E           0.0150
# 8            Thiamin           0.0012
# 9         Riboflavin           0.0013
# 10            Niacin           0.0160
# 11        Vitamin B6           0.0017
# 15  Pantothenic acid           0.0050
# 16        Phosphorus           1.2500
# 18         Magnesium           0.4200
# 19              Zinc           0.0110
# 21            Copper           0.0009
# 22         Manganese           0.0023
# 25          Chloride           2.3000
# 26         Potassium           4.7000
# 27           Choline           0.5500

# %%
df_add2 = df1[(df1['Unnamed: 1'] != 'Milligrams (mg)') 
  & (df1['Unnamed: 1'] != 'Milligrams NE5 (mg)') & (df1['Unnamed: 1'] != 'Milligrams (mg)4')]
df_add2['Unnamed: 2'] = df_add2['Unnamed: 2'].astype(float) / 10 ** 6
df_add2.drop(columns=['Unnamed: 1', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], inplace=True)
df_add2.rename(columns={'RDIs - Nutrients' : 'Nutrient', 'Unnamed: 2' : 'Daily dose in G'}, inplace=True)
df_add2
# Out:
# /var/folders/zz/zyxvpxvq6csfxvn_n003vm3w00yx0z/T/ipykernel_78052/3002502948.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_add2['Unnamed: 2'] = df_add2['Unnamed: 2'].astype(float) / 10 ** 6
# /var/folders/zz/zyxvpxvq6csfxvn_n003vm3w00yx0z/T/ipykernel_78052/3002502948.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_add2.drop(columns=['Unnamed: 1', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], inplace=True)
# /var/folders/zz/zyxvpxvq6csfxvn_n003vm3w00yx0z/T/ipykernel_78052/3002502948.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_add2.rename(columns={'RDIs - Nutrients' : 'Nutrient', 'Unnamed: 2' : 'Daily dose in G'}, inplace=True)
#        Nutrient  Daily dose in G
# 1     Vitamin A         0.000900
# 5     Vitamin D         0.000020
# 7     Vitamin K         0.000120
# 12      Folate6         0.000400
# 13  Vitamin B12         0.000002
# 14       Biotin         0.000030
# 17       Iodine         0.000150
# 20     Selenium         0.000055
# 23     Chromium         0.000035
# 24   Molybdenum         0.000045

# %%
daily_reference = daily_reference.append(df_add1, ignore_index=True)
daily_reference = daily_reference.append(df_add2, ignore_index=True)
daily_reference
# Out:
# /var/folders/zz/zyxvpxvq6csfxvn_n003vm3w00yx0z/T/ipykernel_78052/1753316254.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   daily_reference = daily_reference.append(df_add1, ignore_index=True)
# /var/folders/zz/zyxvpxvq6csfxvn_n003vm3w00yx0z/T/ipykernel_78052/1753316254.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   daily_reference = daily_reference.append(df_add2, ignore_index=True)
#                 Nutrient  Daily dose in G
# 0                    Fat        78.000000
# 1          Saturated fat        20.000000
# 2            Cholesterol         0.300000
# 3   Total\rcarbohydrates       275.000000
# 4                 Sodium         2.300000
# 5          Dietary Fiber        28.000000
# 6                Protein        50.000000
# 7           Added sugars        50.000000
# 8              Vitamin C         0.090000
# 9                Calcium         1.300000
# 10                  Iron         0.018000
# 11             Vitamin E         0.015000
# 12               Thiamin         0.001200
# 13            Riboflavin         0.001300
# 14                Niacin         0.016000
# 15            Vitamin B6         0.001700
# 16      Pantothenic acid         0.005000
# 17            Phosphorus         1.250000
# 18             Magnesium         0.420000
# 19                  Zinc         0.011000
# 20                Copper         0.000900
# 21             Manganese         0.002300
# 22              Chloride         2.300000
# 23             Potassium         4.700000
# 24               Choline         0.550000
# 25             Vitamin A         0.000900
# 26             Vitamin D         0.000020
# 27             Vitamin K         0.000120
# 28               Folate6         0.000400
# 29           Vitamin B12         0.000002
# 30                Biotin         0.000030
# 31                Iodine         0.000150
# 32              Selenium         0.000055
# 33              Chromium         0.000035
# 34            Molybdenum         0.000045

# %%
daily_reference.to_csv('../data/daily_reference.csv')

# %%
daily_portion = {}
for k, v in daily_reference.set_index('Nutrient').T.to_dict('list').items():
  daily_portion[k] = v[0]
daily_portion
# Out:
# {'Fat': 78.0,
#  'Saturated fat': 20.0,
#  'Cholesterol': 0.3,
#  'Total\rcarbohydrates': 275.0,
#  'Sodium': 2.3,
#  'Dietary Fiber': 28.0,
#  'Protein': 50.0,
#  'Added sugars': 50.0,
#  'Vitamin C': 0.09,
#  'Calcium': 1.3,
#  'Iron': 0.018,
#  'Vitamin E': 0.015,
#  'Thiamin': 0.0012,
#  'Riboflavin': 0.0013,
#  'Niacin': 0.016,
#  'Vitamin B6': 0.0017,
#  'Pantothenic acid': 0.005,
#  'Phosphorus': 1.25,
#  'Magnesium': 0.42,
#  'Zinc': 0.011,
#  'Copper': 0.0009,
#  'Manganese': 0.0023,
#  'Chloride': 2.3,
#  'Potassium': 4.7,
#  'Choline': 0.55,
#  'Vitamin A': 0.0009,
#  'Vitamin D': 2e-05,
#  'Vitamin K': 0.00012,
#  'Folate6': 0.0004,
#  'Vitamin B12': 2.4e-06,
#  'Biotin': 3e-05,
#  'Iodine': 0.00015,
#  'Selenium': 5.5e-05,
#  'Chromium': 3.5e-05,
#  'Molybdenum': 4.5e-05}

# %%
api_key = 'SmPYB4v9WYhjeLd9zHtDCstEhi11uy9iJ2Vg2ha6'
def get_nutrition_info(ingredients):
  nuts = {}
  for ingredient in ingredients:
    before = ingredient
    ingr = ingredient.split(' ')
    if len(ingr) != 1:
        ingredient = ''
        for i in range(len(ingr)):
            ingredient += ingr[i]
            if i != len(ingr) - 1:
                ingredient += '%'
    url = f'https://api.nal.usda.gov/fdc/v1/foods/search?api_key=DEMO_KEY&query={ingredient}'
    session = requests.Session()
    session.headers = {
          'user-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 YaBrowser/21.8.3.607 Yowser/2.5 Safari/537.36'}
    page = session.get(
              url,
              timeout=(60,60),
              stream=True, proxies = {"http": "http://194.5.193.183:80"},
              auth=(api_key, '')
          )
    info = page.json()
    nutrients = info['foods'][0]['foodNutrients']
    nutr_info = {}
    for nutrient in nutrients:
      nutr_info[nutrient['nutrientName']] = [nutrient['value'], nutrient['unitName']]
    nuts[before] = nutr_info
  return nuts

# %%
nuts = get_nutrition_info(['yogurt', 'bean'])
nuts
# Out:
# {'yogurt': {'Fiber, total dietary': [0.0, 'G'],
#   'Calcium, Ca': [118, 'MG'],
#   'Iron, Fe': [0.0, 'MG'],
#   'Vitamin A, IU': [59.0, 'IU'],
#   'Vitamin C, total ascorbic acid': [0.7, 'MG'],
#   'Protein': [2.94, 'G'],
#   'Total lipid (fat)': [2.94, 'G'],
#   'Carbohydrate, by difference': [15.9, 'G'],
#   'Energy': [94.0, 'KCAL'],
#   'Sugars, total including NLEA': [15.9, 'G'],
#   'Sodium, Na': [41.0, 'MG'],
#   'Cholesterol': [12.0, 'MG'],
#   'Fatty acids, total saturated': [1.76, 'G']},
#  'bean': {'Protein': [5.44, 'G'],
#   'Total lipid (fat)': [3.7, 'G'],
#   'Carbohydrate, by difference': [15.9, 'G'],
#   'Energy': [119, 'KCAL'],
#   'Alcohol, ethyl': [0.0, 'G'],
#   'Water': [73.0, 'G'],
#   'Caffeine': [0.0, 'MG'],
#   'Theobromine': [0.0, 'MG'],
#   'Sugars, total including NLEA': [0.99, 'G'],
#   'Fiber, total dietary': [4.9, 'G'],
#   'Calcium, Ca': [26.0, 'MG'],
#   'Iron, Fe': [1.6, 'MG'],
#   'Magnesium, Mg': [40.0, 'MG'],
#   'Phosphorus, P': [105, 'MG'],
#   'Potassium, K': [368, 'MG'],
#   'Sodium, Na': [443, 'MG'],
#   'Zinc, Zn': [0.69, 'MG'],
#   'Copper, Cu': [0.196, 'MG'],
#   'Selenium, Se': [7.7, 'UG'],
#   'Retinol': [0.0, 'UG'],
#   'Vitamin A, RAE': [0.0, 'UG'],
#   'Carotene, beta': [0.0, 'UG'],
#   'Carotene, alpha': [0.0, 'UG'],
#   'Vitamin E (alpha-tocopherol)': [0.91, 'MG'],
#   'Vitamin D (D2 + D3)': [0.0, 'UG'],
#   'Cryptoxanthin, beta': [0.0, 'UG'],
#   'Lycopene': [0.0, 'UG'],
#   'Lutein + zeaxanthin': [0.0, 'UG'],
#   'Vitamin C, total ascorbic acid': [0.6, 'MG'],
#   'Thiamin': [0.09, 'MG'],
#   'Riboflavin': [0.1, 'MG'],
#   'Niacin': [0.43, 'MG'],
#   'Vitamin B-6': [0.115, 'MG'],
#   'Folate, total': [21.0, 'UG'],
#   'Vitamin B-12': [0.0, 'UG'],
#   'Choline, total': [16.3, 'MG'],
#   'Vitamin K (phylloquinone)': [1.7, 'UG'],
#   'Folic acid': [0.0, 'UG'],
#   'Folate, food': [21.0, 'UG'],
#   'Folate, DFE': [21.0, 'UG'],
#   'Vitamin E, added': [0.0, 'MG'],
#   'Vitamin B-12, added': [0.0, 'UG'],
#   'Cholesterol': [0.0, 'MG'],
#   'Fatty acids, total saturated': [0.529, 'G'],
#   'SFA 4:0': [0.0, 'G'],
#   'SFA 6:0': [0.0, 'G'],
#   'SFA 8:0': [0.001, 'G'],
#   'SFA 10:0': [0.005, 'G'],
#   'SFA 12:0': [0.001, 'G'],
#   'SFA 14:0': [0.005, 'G'],
#   'SFA 16:0': [0.423, 'G'],
#   'SFA 18:0': [0.061, 'G'],
#   'MUFA 18:1': [0.842, 'G'],
#   'PUFA 18:2': [1.76, 'G'],
#   'PUFA 18:3': [0.193, 'G'],
#   'PUFA 20:4': [0.002, 'G'],
#   'PUFA 22:6 n-3 (DHA)': [0.0, 'G'],
#   'MUFA 16:1': [0.003, 'G'],
#   'PUFA 18:4': [0.0, 'G'],
#   'MUFA 20:1': [0.012, 'G'],
#   'PUFA 2:5 n-3 (EPA)': [0.0, 'G'],
#   'MUFA 22:1': [0.0, 'G'],
#   'PUFA 22:5 n-3 (DPA)': [0.0, 'G'],
#   'Fatty acids, total monounsaturated': [0.859, 'G'],
#   'Fatty acids, total polyunsaturated': [1.96, 'G']}}

# %%
def get_nutritions(nuts):
    res = {}
    for kn, vn in nuts.items():
        res_nutr = {}
        for kv,vv in vn.items():
            for key, value in daily_portion.items():
                if kv.lower().find(key.lower()) != -1:
                    if key not in res_nutr and vv[0] != 0:
                        res_val = 1 / value
                    if vv[1] == 'MG':
                        res_val /= 10 ** 3
                    elif vv[1] == 'UG':
                        res_val /= 10 ** 6
                    elif vv[1] == 'IU' and key.find('Vitamin D') != -1:
                        res_val = res_val * 0.6 / 10 ** 6
                    elif vv[1] == 'IU':
                        res_val = res_val * 25 / 10 ** 9
                    res_val *= vv[0]
                    res_nutr[key] = res_val
        res[kn] = res_nutr
    return res

# %%
def print_nutrition(res):
  for k,v in res.items():
    print(k.capitalize())
    for name, part in v.items():
      print(f'{name} - {part:.0%} of Daily Value')
    print('')

# %%
g_ingredients = []

# %%
with open('../data/epi_r_cut.csv') as f:
    ingr = f.readline()
ingredients = ingr[:-1].split(',')
ingredients
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 with open('../data/epi_r_cut.csv') as f:
#       2     ingr = f.readline()
#       3 ingredients = ingr[:-1].split(',')
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/epi_r_cut.csv'

# %%
def split(a, n):
    k, m = divmod(len(a), n)
    b = []
    for i in range(n):
      b.append(a[i*k+min(i, m):(i+1)*k+min(i+1, m)])
    return b
lists_of_ingr = split(ingredients, 30)
lists_of_ingr

# %%
def get_nutrition_info_all(ingredients):
  nuts = {}
  for ingredient in ingredients:
    before = ingredient
    ingr = ingredient.split(' ')
    if len(ingr) != 1:
        ingredient = ''
        for i in range(len(ingr)):
            ingredient += ingr[i]
            if i != len(ingr) - 1:
                ingredient += '%'
    url = f'https://api.nal.usda.gov/fdc/v1/foods/search?api_key=DEMO_KEY&query={ingredient}'
    session = requests.Session()
    session.headers = {
          'user-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 YaBrowser/21.8.3.607 Yowser/2.5 Safari/537.36'}
    page = session.get(
              url,
              timeout=(60,60),
              stream=True, proxies = {"http": "http://194.5.193.183:80"},
              auth=(api_key, '')
          )
    info = page.json()
    nutrients = info['foods'][0]['foodNutrients']
    nutr_info = {}
    for nutrient in nutrients:
      nutr_info[nutrient['nutrientName']] = [nutrient['value'], nutrient['unitName']]
    nuts[before] = nutr_info
    g_ingredients.append(nuts)
    time.sleep(5)
  return nuts

# %%
g_ingredients

# %%
for i in range(len(lists_of_ingr)):
  if i != 0:
    get_nutrition_info_all(lists_of_ingr[i])
  time.sleep(20)

# %%
res = {}
for i in g_ingredients:
  for kn, vn in i.items():
    res_nutr = {}
    for kv,vv in vn.items():
      for key, value in daily_portion.items():
        if kv.lower().find(key.lower()) != -1:
          if key not in res_nutr and vv[0] != 0:
            res_val = 100 / value
            if vv[1] == 'MG':
              res_val /= 10 ** 3
            elif vv[1] == 'UG':
              res_val /= 10 ** 6
            elif vv[1] == 'IU' and key.find('Vitamin D') != -1:
              res_val = res_val * 0.6 / 10 ** 6
            elif vv[1] == 'IU':
              res_val = res_val * 25 / 10 ** 9
            res_val *= vv[0]
            res_nutr[key] = res_val
    res[kn] = res_nutr
# just print
for k,v in res.items():
  print(k,v)

# %%
df = pd.DataFrame(columns=daily_portion.keys())
for i in range(len(res)):
  row = pd.Series(list(res.values())[i], name=list(res.keys())[i])
  df = df.append(row)
df.fillna(0, inplace=True)
df = df.round(1)
df

# %%
df.to_csv('nutrition_info.csv')
