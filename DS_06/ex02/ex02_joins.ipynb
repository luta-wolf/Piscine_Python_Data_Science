# %%
import pandas as pd
import sqlite3

# %% [markdown]
# • create a connection to the database using the library sqlite3

# %%
db_con = sqlite3.connect('../checking-logs.sqlite.sqlite')

# %% [markdown]
# <h2>• create a new table datamart in the database by joining the tables pageviews and
# checker using only one query</h2><br>
# ◦ the table should have the following columns: uid, labname, first_commit_ts,
# first_view_ts<br>
# ◦ first_commit_ts is just a new name of the column timestamp from the checker
# table, it shows the first commit from a particular lab and from a particular
# user<br>
# ◦ first_view_ts is the first visit of a user to the table pageviews, timestamp
# when a user visited the newsfeed<br>
# ◦ status = ’ready’ should still be a filter<br>
# ◦ numTrials = 1 should still be a filter<br>
# ◦ labnames should still be from the list: ’laba04’, ’laba04s’, ’laba05’, ’laba06’,
# ’laba06s’, ’project1’<br>
# ◦ the table should contain only the users (uids with user_*) and not the admins<br>
# ◦ first_commit_ts and first_view_ts should be parsed as datetime64[ns]

# %%
query = "SELECT checker.uid, checker.labname, \
checker.timestamp AS 'first_commit_ts', \
pageviews.datetime as 'first_view_ts' \
from checker \
LEFT JOIN pageviews ON checker.uid=pageviews.uid \
WHERE checker.status='ready' AND checker.numtrials=1 \
AND checker.labname IN ('laba04', 'laba04s', 'laba05', 'laba06', 'laba06s', 'project1') \
AND checker.uid LIKE 'user_%' \
AND (pageviews.datetime in \
(SELECT info_time from \
(SELECT uid, MIN(datetime) as info_time \
from pageviews group by uid)) or pageviews.datetime is NULL)"
datamart = pd.io.sql.read_sql(query, db_con, parse_dates=['first_commit_ts', 'first_view_ts'])
datamart
# Out:
#          uid   labname            first_commit_ts              first_view_ts
# 0     user_4  project1 2020-04-17 05:19:02.744528                        NaT
# 1     user_4    laba04 2020-04-17 11:33:17.366400                        NaT
# 2     user_4   laba04s 2020-04-17 11:48:41.992466                        NaT
# 3    user_17  project1 2020-04-18 07:56:45.408648 2020-04-18 10:56:55.833899
# 4    user_30    laba04 2020-04-18 13:36:53.971502 2020-04-17 22:46:26.785035
# ..       ...       ...                        ...                        ...
# 135  user_23    laba06 2020-05-21 08:34:10.517205                        NaT
# 136  user_19   laba06s 2020-05-21 13:27:06.705881 2020-04-21 20:30:38.034966
# 137  user_23   laba06s 2020-05-21 14:29:15.709568                        NaT
# 138  user_17    laba06 2020-05-21 15:21:31.567615 2020-04-18 10:56:55.833899
# 139  user_17   laba06s 2020-05-21 17:39:17.783615 2020-04-18 10:56:55.833899
#
# [140 rows x 4 columns]

# %%
datamart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   uid              140 non-null    object
#  1   labname          140 non-null    object
#  2   first_commit_ts  140 non-null    datetime64[ns]
#  3   first_view_ts    59 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), object(2)
# memory usage: 4.5+ KB

# %% [markdown]
# <h2>• using Pandas methods, create two dataframes: test and control</h2><br>
# ◦ test should have the users that have the values in first_view_ts<br>
# ◦ control should have the users that have missing values in first_view_ts<br>
# ◦ replace the missing values in the control with the average first_view_ts of the
# test users, we will use this value for the future analysis<br>
# ◦ save both tables into the database, you will use them in the next exercises

# %%
test = datamart[datamart['first_view_ts'].notnull()]
test
# Out:
#          uid   labname            first_commit_ts              first_view_ts
# 3    user_17  project1 2020-04-18 07:56:45.408648 2020-04-18 10:56:55.833899
# 4    user_30    laba04 2020-04-18 13:36:53.971502 2020-04-17 22:46:26.785035
# 7    user_30   laba04s 2020-04-18 14:51:37.498399 2020-04-17 22:46:26.785035
# 8    user_14    laba04 2020-04-18 15:14:00.312338 2020-04-18 10:53:52.623447
# 11   user_14   laba04s 2020-04-18 22:30:30.247628 2020-04-18 10:53:52.623447
# 18   user_19    laba04 2020-04-20 19:05:01.297780 2020-04-21 20:30:38.034966
# 19   user_25    laba04 2020-04-20 19:16:50.673054 2020-05-09 23:54:54.260791
# 20   user_21    laba04 2020-04-21 17:48:00.487806 2020-04-22 22:40:36.824081
# 21   user_30  project1 2020-04-22 12:36:24.053518 2020-04-17 22:46:26.785035
# 23   user_21   laba04s 2020-04-22 20:09:21.857747 2020-04-22 22:40:36.824081
# 24   user_28    laba04 2020-04-22 21:47:19.707242 2020-05-10 21:07:50.350946
# ...

# %%
control = datamart[datamart['first_view_ts'].isnull()]
control
# Out:
#          uid   labname            first_commit_ts first_view_ts
# 0     user_4  project1 2020-04-17 05:19:02.744528           NaT
# 1     user_4    laba04 2020-04-17 11:33:17.366400           NaT
# 2     user_4   laba04s 2020-04-17 11:48:41.992466           NaT
# 5     user_2    laba04 2020-04-18 13:42:35.482008           NaT
# 6     user_2   laba04s 2020-04-18 13:51:22.291271           NaT
# ..       ...       ...                        ...           ...
# 126   user_2   laba06s 2020-05-19 14:45:03.908268           NaT
# 132   user_6   laba06s 2020-05-20 14:50:07.609937           NaT
# 134   user_7   laba06s 2020-05-20 23:05:37.742597           NaT
# 135  user_23    laba06 2020-05-21 08:34:10.517205           NaT
# 137  user_23   laba06s 2020-05-21 14:29:15.709568           NaT
#
# [81 rows x 4 columns]

# %%
avg = test['first_view_ts'].mean()
control.fillna(avg, inplace=True)
control
# Out:
# /var/folders/zz/zyxvpxvq6csfxvn_n003vm3w00yx0z/T/ipykernel_38726/4222876771.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control.fillna(avg, inplace=True)
#          uid   labname            first_commit_ts  \
# 0     user_4  project1 2020-04-17 05:19:02.744528
# 1     user_4    laba04 2020-04-17 11:33:17.366400
# 2     user_4   laba04s 2020-04-17 11:48:41.992466
# 5     user_2    laba04 2020-04-18 13:42:35.482008
# 6     user_2   laba04s 2020-04-18 13:51:22.291271
# ..       ...       ...                        ...
# 126   user_2   laba06s 2020-05-19 14:45:03.908268
# 132   user_6   laba06s 2020-05-20 14:50:07.609937
# 134   user_7   laba06s 2020-05-20 23:05:37.742597
# 135  user_23    laba06 2020-05-21 08:34:10.517205
# 137  user_23   laba06s 2020-05-21 14:29:15.709568
#
# ...

# %%
test.to_sql('test', db_con)
control.to_sql('control', db_con)
# Out:
# 81

# %% [markdown]
# • close the connection

# %%
db_con.close()
