# %%
from module.tags import Tags
from module.links import Links
from module.movies import Movies
from module.ratings import Ratings

# %% [markdown]
# ### TAGS

# %%
tags = Tags('data/tags.csv')

# %%
# %timeit tags.most_words(10)
# Out:
# 1.73 ms ± 35.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit tags.longest(3)
# Out:
# 468 µs ± 14.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit tags.most_words_and_longest(3)
# Out:
# 2.17 ms ± 14.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit tags.most_popular(3)
# Out:
# 557 µs ± 6.32 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit tags.tags_with('Netflix')
# Out:
# 613 µs ± 5.31 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ### LINKS

# %%
links = Links('data/links.csv')

# %%
# %timeit links.get_imdb(['1','2','3'], ['Director', 'Also known as', 'Budget', 'Gross worldwide','Runtime'])
# Out:
# 3.97 s ± 243 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit links.top_directors(5)
# Out:
# 5.85 µs ± 40 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit links.most_expensive(10)
# Out:
# 6.8 µs ± 98.2 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit links.most_profitable(10)
# Out:
# 10.4 µs ± 120 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit links.longest(10)
# Out:
# 8.21 µs ± 107 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit links.top_cost_per_minute(10)
# Out:
# 14.7 µs ± 233 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# ### MOVIES

# %%
movies = Movies('data/movies.csv')

# %%
# %timeit movies.dist_by_release()
# Out:
# 16 ms ± 195 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit movies.dist_by_genres()

# %%
# %timeit movies.most_genres(5)
# Out:
# 18.9 ms ± 652 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### RATINGS

# %%
ratings = Ratings('data/ratings.csv')
ratings_movies = Ratings.Movies(ratings, movies)
ratings_users = Ratings.Users(ratings, movies)

# %%
# %timeit ratings_movies.dist_by_year()
# Out:
# 201 ms ± 1.59 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
for key, value in ratings_movies.dist_by_year().items():
    print(f'{key:<8}{value}')
# Out:
# 1996    6040
# 1997    1916
# 1998    507
# 1999    2439
# 2000    10061
# 2001    3922
# 2002    3478
# 2003    4014
# 2004    3279
# 2005    5813
# 2006    4059
# 2007    7114
# 2008    4351
# 2009    4158
# 2010    2300
# 2011    1690
# 2012    4657
# 2013    1664
# 2014    1439
# 2015    6616
# 2016    6702
# 2017    8199
# 2018    6418

# %%
# %timeit ratings_movies.dist_by_rating()
# Out:
# 114 ms ± 1.2 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
for key, value in ratings_movies.dist_by_rating().items():
    print(f'{key:<8}{value}')
# Out:
# 0.5     1370
# 1.0     2811
# 1.5     1791
# 2.0     7551
# 2.5     5550
# 3.0     20047
# 3.5     13136
# 4.0     26818
# 4.5     8551
# 5.0     13211

# %%
# %timeit ratings_movies.top_by_num_of_ratings(5)
# Out:
# 144 ms ± 1.33 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
for key, value in ratings_movies.top_by_num_of_ratings(5).items():
    print(f'{key:<8}{value}')
# Out:
# Forrest Gump (1994)329
# Shawshank Redemption, The (1994)317
# Pulp Fiction (1994)307
# Silence of the Lambs, The (1991)279
# Matrix, The (1999)278

# %%
# %timeit ratings_movies.top_by_ratings(5)
# Out:
# 162 ms ± 2.88 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
for key, value in ratings_movies.top_by_ratings(5).items():
    print(f'{key:<8}{value}')
# Out:
# The Jinx: The Life and Deaths of Robert Durst (2015)5.0
# Galaxy of Terror (Quest) (1981)5.0
# Alien Contamination (1980)5.0
# I'm the One That I Want (2000)5.0
# Lesson Faust (1994)5.0

# %%
# %timeit ratings_movies.top_controversial(5)
# Out:
# 175 ms ± 2.09 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
for key, value in ratings_movies.top_controversial(5).items():
    print(f'{key:<8}{value}')
# Out:
# Troll 2 (1990)5.42
# Ivan's Childhood (a.k.a. My Name is Ivan) (Ivanovo detstvo) (1962)5.03
# The Jinx: The Life and Deaths of Robert Durst (2015)5.0
# Galaxy of Terror (Quest) (1981)5.0
# Alien Contamination (1980)5.0

# %%
# %timeit ratings_users.dist_by_ratings_number()
# Out:
# 111 ms ± 1.22 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
for key, value in ratings_users.dist_by_ratings_number().items():
    print(f'{key:<8}{value}')
# Out:
# 53      20
# 147     20
# 189     20
# 194     20
# 207     20
# 257     20
# 278     20
# 320     20
# 406     20
# 431     20
# 442     20
# 569     20
# 576     20
# 595     20
# 26      21
# 37      21
# 49      21
# 87      21
# 157     21
# 245     21
# 281     21
# 293     21
# 324     21
# 364     21
# 439     21
# 507     21
# 547     21
# 549     21
# 598     21
# 60      22
# 118     22
# 120     22
# 127     22
# 138     22
# 192     22
# 214     22
# 407     22
# 433     22
# 467     22
# 478     22
# 494     22
# 531     22
# 544     22
# 35      23
# 145     23
# 163     23
# 251     23
# 299     23
# 329     23
# 394     23
# 397     23
# 423     23
# 485     23
# 545     23
# 568     23
# 574     23
# 92      24
# 175     24
# 180     24
# 231     24
# 289     24
# 508     24
# 518     24
# 55      25
# 173     25
# 206     25
# 228     25
# 258     25
# 333     25
# 360     25
# 392     25
# 529     25
# 25      26
# 81      26
# 150     26
# 158     26
# ...

# %%
# %timeit ratings_users.dist_by_ratings_values()
# Out:
# 115 ms ± 1.19 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
for key, value in ratings_users.dist_by_ratings_values().items():
    print(f'{key:<8}{value}')
# Out:
# 442     1.27
# 139     2.14
# 508     2.15
# 153     2.22
# 567     2.25
# 311     2.34
# 298     2.36
# 517     2.39
# 308     2.43
# 3       2.44
# 22      2.57
# 255     2.57
# 571     2.57
# 297     2.6
# 19      2.61
# 294     2.61
# 287     2.62
# 293     2.62
# 36      2.63
# 333     2.64
# 428     2.64
# 599     2.64
# 307     2.67
# 535     2.67
# 160     2.71
# 245     2.71
# 149     2.72
# 431     2.73
# 365     2.75
# 386     2.75
# 217     2.76
# 81      2.77
# 50      2.78
# 481     2.81
# 478     2.82
# 55      2.84
# 368     2.84
# 448     2.85
# 214     2.86
# 230     2.86
# 329     2.87
# 207     2.88
# 510     2.9
# 181     2.94
# 338     2.94
# 342     2.94
# 461     2.94
# 394     2.96
# 600     2.99
# 133     3.0
# 163     3.0
# 316     3.0
# 28      3.02
# 489     3.02
# 54      3.03
# 94      3.04
# 132     3.04
# 47      3.05
# 314     3.05
# 395     3.05
# 416     3.07
# 76      3.08
# 384     3.09
# 427     3.1
# 576     3.1
# 127     3.11
# 262     3.11
# ...

# %%
# %timeit ratings_users.top_by_variance(5)
# Out:
# 151 ms ± 1.96 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
for key, value in ratings_users.top_by_variance(5).items():
    print(f'{key:<8}{value}')
# Out:
# 70946   5.42
# 32892   5.03
# 131724  5.0
# 5746    5.0
# 6835    5.0
